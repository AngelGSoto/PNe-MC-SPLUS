# %%
import pandas as pd
from astropy.table import Table
import glob

# %%
df = pd.read_csv("../STARS/MC-STAR-16r18-StN3.csv")

# %%
df
# Out:
#              Field                        ID       RA_r     DEC_r      X_r  \
# 0        b'MC0118'  b'iDR4_3_MC0118_0004285'  27.949976 -74.07411  6346.61
# 1        b'MC0118'  b'iDR4_3_MC0118_0004490'  30.769316 -74.05729  1279.28
# 2        b'MC0118'  b'iDR4_3_MC0118_0005215'  27.994871 -74.05575  6266.83
# 3        b'MC0118'  b'iDR4_3_MC0118_0005398'  27.357098 -74.04949  7414.29
# 4        b'MC0118'  b'iDR4_3_MC0118_0005981'  28.837078 -74.03711  4751.58
# ...            ...                       ...        ...       ...      ...
# 1455439  b'MC0118'  b'iDR4_3_MC0118_0003207'  27.443493 -74.09320  7254.22
# 1455440  b'MC0118'  b'iDR4_3_MC0118_0003723'  29.569403 -74.08045  3438.81
# 1455441  b'MC0118'  b'iDR4_3_MC0118_0003570'  28.258670 -74.08750  5791.92
# 1455442  b'MC0118'  b'iDR4_3_MC0118_0003738'  26.757875 -74.07767  8486.82
# 1455443  b'MC0118'  b'iDR4_3_MC0118_0003603'  26.385925 -74.07728  9154.57
#
# ...
