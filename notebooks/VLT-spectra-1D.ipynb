# %%
import numpy as np
import sep
import os 
# additional setup for reading the test image and displaying plots
#import fitsio
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = [18., 15.]

# %%
datadir = "../PN_atlas_datapack_v1/1D"
fitsfile = "SMC-SMP-2_spectrum.fits"
hdulist= fits.open(os.path.join(datadir, fitsfile))

# %%
hdulist.info()
# Out:
# Filename: ../PN_atlas_datapack_v1/1D/SMC-SMP-2_spectrum.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     16   59047R x 4C   [D, D, D, D]

# %%
hdulist[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   32 / length of dimension 1
# NAXIS2  =                59047 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    4 / number of table fields
# TTYPE1  = 'WAVE    '
# TFORM1  = 'D       '
# TTYPE2  = 'FLUX    '
# TFORM2  = 'D       '
# TTYPE3  = 'RED     '
# TFORM3  = 'D       '
# TTYPE4  = 'ERR     '
# TFORM4  = 'D       '

# %%
data = hdulist[1].data

# %%
data
# Out:
# FITS_rec([( 2989.94682402, 1.09330587e-15,  8.92834006e-16, 6.55303016e-15),
#           ( 2990.14686543, 1.45996790e-15,  1.25840687e-15, 6.74336397e-15),
#           ( 2990.34690684, 6.68443208e-15,  6.48178330e-15, 7.04397004e-15),
#           ...,
#           (23998.34290546, 1.15894765e-17, -1.09424144e-18, 2.35721920e-17),
#           (23998.94304375, 3.89426700e-18, -8.79546894e-18, 2.35897835e-17),
#           (23999.54318205, 3.42577906e-18, -9.26998836e-18, 2.18839408e-17)],
#          dtype=(numpy.record, [('WAVE', '>f8'), ('FLUX', '>f8'), ('RED', '>f8'), ('ERR', '>f8')]))

# %%
wl = data["WAVE"]
flux = data["FLUX"]

# %%
fig, ax = plt.subplots(figsize=(11, 5))
#ax.set_title(namefile)
ax.set(xlim=[3600,9000])
plt.ylim(ymin=-1e-13,ymax=2e-12)
ax.set(xlabel='Wavelength $(\AA)$')
ax.set(ylabel='Flux')
ax.plot(wl, flux, linewidth=0.9, zorder=5)
ax.axvline(6560.28, color='k', linewidth=0.5, linestyle='--', label=r"H$\alpha$")
ax.axvline(5000.7, color='k', linewidth=0.5, linestyle='-', label="[O III]")
ax.axvline(4686, color='r', linewidth=0.5, linestyle='-', label="He II")
ax.axvline(7751, color='y', linewidth=0.4, linestyle='-.', label="[Ar III] 7751")
ax.axvline(7135, color='k', linewidth=0.4, linestyle='-.', label="[Ar III] 7135")
ax.legend()
#ra = hdu[0].header["RA"]
#dec = hdu[0].header["DEC"
#print("Nome file:", namefile, "=>", "RA and DEC:", ra, dec)

# %%
fig, ax = plt.subplots(figsize=(11, 5))
#ax.set_title(namefile)
ax.set(xlim=[4900,5020])
plt.ylim(ymin=-1e-13,ymax=2e-12)
ax.set(xlabel='Wavelength $(\AA)$')
ax.set(ylabel='Flux')
ax.plot(wl, flux, linewidth=0.9, zorder=5)
ax.axvline(6560.28, color='k', linewidth=0.5, linestyle='--', label=r"H$\alpha$")
ax.axvline(5000.7, color='k', linewidth=0.5, linestyle='-', label="[O III]")
ax.axvline(4686, color='r', linewidth=0.5, linestyle='-', label="He II")
ax.axvline(7751, color='y', linewidth=0.4, linestyle='-.', label="[Ar III] 7751")
ax.axvline(7135, color='k', linewidth=0.4, linestyle='-.', label="[Ar III] 7135")
ax.legend()
#ra = hdu[0].header["RA"]
#dec = hdu[0].header["DEC"
#print("Nome file:", namefile, "=>", "RA and DEC:", ra, dec)
