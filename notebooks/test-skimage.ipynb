# %%
from astropy.io import fits
import numpy as np
import skimage.data
from skimage import img_as_float
from skimage.restoration import denoise_wavelet, cycle_spin
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %matplotlib inline

rcParams['figure.figsize'] = [18., 15.]

# %%
hdu= fits.open("../images/MGPNSMC9_14.67887_-72.45467_r.fits")

# %%
hdu

# %%
hdu[0].data
# Out:
# array([[ 0.2339493 ,  0.09015772, -0.19452856, ..., -0.00388106,
#         -0.09992909, -0.25183013],
#        [ 0.23374775, -0.07826337, -0.34126177, ..., -0.29986596,
#         -0.2245543 , -0.2418875 ],
#        [ 0.16366321, -0.03200011, -0.04358648, ..., -0.19160442,
#         -0.40352535, -0.23165213],
#        ...,
#        [-0.1329252 ,  0.21583426,  0.6263116 , ..., -0.25368086,
#         -0.09574094, -0.2751149 ],
#        [-0.07026844, -0.20234482,  0.8945233 , ..., -0.09315379,
#         -0.14195053, -0.35206363],
#        [ 0.11197681, -0.27712798,  0.40015072, ...,  0.12249679,
#          0.03645505, -0.02301022]], dtype=float32)

# %%
# show the image
m, s = np.mean(hdu[0].data), np.std(hdu[0].data)
plt.imshow(hdu[0].data, interpolation='nearest', cmap='gray', vmin=m-s, vmax=m+s, origin='lower')
plt.colorbar();
#plt.savefig("difference_Ha.jpg")

# %%
denoised_data = denoise_wavelet(hdu[0].data, sigma=0.1, rescale_sigma=True)

# %%
m, s = np.mean(hdu[0].data), np.std(hdu[0].data)
plt.imshow(denoised_data, interpolation='nearest', vmin=m-s, vmax=m+s, cmap='gray', origin='lower')
plt.colorbar();
