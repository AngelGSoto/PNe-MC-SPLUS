# %%
import splusdata
import getpass
import pandas as pd
from astropy.table import Table
# Out:
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]

# %%
df = pd.read_csv("PN-MC-1arcsec.csv")

# %%
df
# Out:
#       NUMBER   RAJ2000   DEJ2000         X         Y   SPLUS_U  SPLUS_U_err  \
# 0     6172.0  12.98485 -71.41232   4610.18   2583.91  16.90231        0.013
# 1    14918.0  14.02240 -70.32391   2273.50   9672.60  16.63531        0.017
# 2   112604.0  14.65230 -71.59695   1173.53   1303.46  99.00000       99.000
# 3      717.0  14.91891 -71.63753   9264.04   1055.92  18.41991        0.059
# 4     4716.0  18.04518 -71.44744   2791.13   2328.05  19.10391        0.074
# 5     7933.0  10.34036 -72.75468   2684.03   1963.77  17.45391        0.017
# 6    35553.0   8.16192 -71.69994   6994.62   8892.84  17.36791        0.021
# 7    30113.0  11.74840 -72.82130   8564.41   1521.22  17.77206        0.020
# 8    76098.0  10.85549 -72.63863  10339.12   2657.68  17.13506        0.015
# 9   118842.0  14.12815 -72.45063   3931.85   3977.72  18.34706        0.023
# 10  121726.0  12.86321 -72.43659   6429.07   4076.33  16.48906        0.012
# ...

# %%
colums = ["SimbadName", "_RA", "_DE"]
df = df[colums]

# %%
df
# Out:
#       SimbadName       _RA       _DE
# 0   SMP SMC 17    12.98517 -71.41225
# 1   SMP SMC 20    14.02233 -70.32383
# 2   SMP SMC 22    14.65212 -71.59694
# 3   SMP SMC 25    14.91883 -71.63753
# 4   SMP SMC 34    18.04542 -71.44739
# 5   SMP SMC 5     10.34029 -72.75467
# 6   SMP SMC 2      8.16179 -71.69986
# 7   SMP SMC 10    11.74862 -72.82111
# 8   SMP SMC 8     10.85554 -72.63867
# 9   SMP SMC 21    14.12871 -72.45044
# 10  SMP SMC 16    12.86312 -72.43658
# 11  SMP SMC 24    14.81700 -72.03325
# 12  MGPN SMC 9    14.67887 -72.45467
# 13  SMP SMC 1      5.99433 -73.63444
# 14  MGPN SMC 6    11.10667 -73.86083
# 15  SMP SMC 6     10.36583 -73.78508
# 16  SMP SMC 7     10.61867 -73.34831
# 17  SMP SMC 3      8.59137 -73.22264
# 18  MGPN SMC 2     7.04250 -72.97889
# 19  SMP SMC 15    12.78071 -73.96047
# 20  SMP SMC 12    12.33775 -73.88294
# 21  SMP SMC 13    12.46533 -73.73936
# 22  SMP SMC 14    12.64608 -73.71608
# 23  SMP SMC 32    13.42837 -73.61883
# ...

# %%
df.rename(columns={'_RA': 'RA', '_DE': 'DEC'}, inplace=True)
# Out:
# /home/luis/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df
# Out:
#       SimbadName        RA       DEC
# 0   SMP SMC 17    12.98517 -71.41225
# 1   SMP SMC 20    14.02233 -70.32383
# 2   SMP SMC 22    14.65212 -71.59694
# 3   SMP SMC 25    14.91883 -71.63753
# 4   SMP SMC 34    18.04542 -71.44739
# 5   SMP SMC 5     10.34029 -72.75467
# 6   SMP SMC 2      8.16179 -71.69986
# 7   SMP SMC 10    11.74862 -72.82111
# 8   SMP SMC 8     10.85554 -72.63867
# 9   SMP SMC 21    14.12871 -72.45044
# 10  SMP SMC 16    12.86312 -72.43658
# 11  SMP SMC 24    14.81700 -72.03325
# 12  MGPN SMC 9    14.67887 -72.45467
# 13  SMP SMC 1      5.99433 -73.63444
# 14  MGPN SMC 6    11.10667 -73.86083
# 15  SMP SMC 6     10.36583 -73.78508
# 16  SMP SMC 7     10.61867 -73.34831
# 17  SMP SMC 3      8.59137 -73.22264
# 18  MGPN SMC 2     7.04250 -72.97889
# 19  SMP SMC 15    12.78071 -73.96047
# 20  SMP SMC 12    12.33775 -73.88294
# 21  SMP SMC 13    12.46533 -73.73936
# 22  SMP SMC 14    12.64608 -73.71608
# 23  SMP SMC 32    13.42837 -73.61883
# ...

# %%
df.to_csv("TOP-PNSMC-SPLUS.csv", index = False)
